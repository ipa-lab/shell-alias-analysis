# %%
import sqlite3
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
# %load_ext sql

# %%
# %sql sqlite:///results.db

# %% [markdown]
# # Sudo

# %%
# %%sql
# with total as (select count(*) as total from alias)
# select
#     count(distinct alias_id) as '#',
#     round(count(distinct alias_id)*100.0/total,2) as '%'
# from alias join command using (alias_id)
# join total
# where command.sudo = 1
# Out:
#  * sqlite:///results.db
# Done.
# [(96752, 4.39)]

# %%
# %%sql
# select alias.name, alias.value, count(distinct alias_id) as '#'
# from alias join command using (alias_id)
# where command.sudo = 1
# group by alias.name, alias.value
# order by 3 desc
# limit 20;
# Out:
#  * sqlite:///results.db
# Done.
# [('sniff', "sudo ngrep -d 'en1' -t '^(GET|POST) ' 'tcp and port 80'", 709),
#  ('reboot', 'sudo reboot', 695),
#  ('httpdump', 'sudo tcpdump -i en1 -n -s 0 -w - | grep -a -o -E "Host\\: .* | GET \\/.*"', 685),
#  ('pacman', 'sudo pacman', 615),
#  ('openPorts', 'sudo lsof -i | grep LISTEN', 574),
#  ('lsock', 'sudo /usr/sbin/lsof -i -P', 567),
#  ('emptytrash', "sudo rm -rfv /Volumes/*/.Trashes ; sudo rm -rfv ~/.Trash ; sudo rm -rfv /private/var/log/asl/*.asl ; sqlite3 ~/Library/Preferences/com.apple.LaunchServices.QuarantineEventsV* 'delete from LSQuarantineEvent'", 560),
#  ('spotoff', 'sudo mdutil -a -i off', 552),
#  ('spoton', 'sudo mdutil -a -i on', 551),
#  ('lsockT', 'sudo /usr/sbin/lsof -nP | grep TCP', 548),
#  ('lsockU', 'sudo /usr/sbin/lsof -nP | grep UDP', 548),
#  ('showBlocked', 'sudo ipfw list', 537),
#  ('svim', 'sudo vim', 526),
#  ('sudo', 'sudo -E', 444),
#  ('apt-get', 'sudo apt-get', 421),
#  ('sv', 'sudo vim', 391),
#  ('install', 'sudo apt-get install', 375),
#  ('editHosts', 'sudo edit /etc/hosts', 348),
#  ('update', 'sudo apt-get update', 347),
#  ('emptytrash', 'sudo rm -rfv /Volumes/*/.Trashes ; sudo rm -rfv ~/.Trash ; sudo rm -rfv /private/var/log/asl/*.asl', 333)]

# %%
# %%sql
# with cmd_total as (select name, count(*) as cmd_total from command group by name)
# select name, count(*) as '#', round(count(*)*100.0/cmd_total,2) as '%'
# from command join cmd_total using (name)
# where sudo = 1
# group by name
# order by count(*) desc
# limit 20;
# Out:
#  * sqlite:///results.db
# Done.
# [('apt-get', 10467, 89.35),
#  ('pacman', 9464, 64.46),
#  ('systemctl', 4978, 57.09),
#  ('apt', 4914, 82.23),
#  ('rm', 4336, 16.25),
#  ('vim', 2472, 5.31),
#  ('shutdown', 2150, 72.46),
#  ('gem', 1852, 66.14),
#  ('killall', 1755, 12.51),
#  ('/usr/sbin/lsof', 1697, 99.41),
#  ('service', 1663, 78.96),
#  ('docker', 1443, 5.16),
#  ('mount', 1436, 56.09),
#  ('mdutil', 1255, 100.0),
#  ('aptitude', 1182, 61.85),
#  ('lsof', 1167, 38.84),
#  ('-E', 1133, 100.0),
#  ('reboot', 1035, 80.8),
#  ('tcpdump', 1032, 92.06),
#  ('softwareupdate', 905, 93.69)]

# %%
# %%sql
# with cmd_total as (select name, count(*) as cmd_total from command group by name)
# select name, count(*) as num, round(count(*)*100.0/cmd_total,2) as per
# from command join cmd_total using (name)
# where sudo = 1
# group by name
# having per < 100
# order by per desc
# limit 20;
# Out:
#  * sqlite:///results.db
# Done.
# [('-u', 500, 99.6),
#  ('abs', 353, 99.44),
#  ('/usr/sbin/lsof', 1697, 99.41),
#  ('-H', 275, 99.28),
#  ('-s', 267, 99.26),
#  ('-i', 461, 99.14),
#  ('discoveryutil', 109, 99.09),
#  ('-S', 101, 99.02),
#  ('ufw', 97, 98.98),
#  ('pacman-mirrors', 135, 98.54),
#  ('fs_usage', 124, 98.41),
#  ('tlp', 61, 98.39),
#  ('$(history -p \\!\\!)', 281, 98.25),
#  ('kextunload', 92, 97.87),
#  ('$(fc -ln -1)', 526, 97.77),
#  ('kextload', 87, 97.75),
#  ('ipfw', 688, 97.73),
#  ('powertop', 104, 97.2),
#  ('/sbin/iptables', 519, 97.19),
#  ('visudo', 34, 97.14)]
